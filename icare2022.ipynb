# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
pd.options.display.max_columns = None

import numpy as np
import os

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
# !head -n 1 ../../icare-dataset_2022-05-vectable/vectable.csv
# Out:
# EPISODIO$NHC$DATA_HORA_ADMISSAO$TIPO_EPISODIO$IDADE$GENERO$ESPECIALIDADE$DEMO_INFO$ICD9$ICD9_INFO$DIAG$DIAG_INFO$ANTPESSOAIS$ANTPESSOAIS_INFO$LABS$LABS_INFO$MEDS$MEDS_INFO$CRONICAS$PATOLOGIAS$CRONICAS_INFO$PATOLOGIAS_INFO$VECTOR$INFO

# %%
with pd.read_csv('../../icare-dataset_2022-05-vectable/vectable.csv',sep='$',chunksize=50_000
                ) as reader:
    for chunk in tqdm(reader):
        chunk
        break
# Out:
# 0it [00:00, ?it/s]
# /home/debian/Simao/miniconda3/envs/thesis/lib/python3.10/site-packages/tqdm/std.py:1195: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   for obj in iterable:
#                                EPISODIO                               NHC  \
# 0                      00000C76BEF1A433  49E15563959186F932CBBD0F55D9061A
# 1      0000C6EB009D41659CB24F7C556DE9A2  509F6AFC33312C427CE35A48C95170AB
# 2                      000125B95FDB9AEB  9A2F0EA29AA2F6A54375AA34BCFE0533
# 3                      00015A736B96C8CE  70C7AB970A8C5325171BE80E7805471C
# 4      000167F76F5A2E9E7455811D978210E3  2CD01E74E03100ACB5B4422C4847F27E
# ...                                 ...                               ...
# 49995  33DF23C8D8ACF1F4F54A476FCC7304FF  E512341FCDB5D939D1DE93955CAC319D
# 49996                  33DF9E4CCDA3E4A9  947F17EB55AF9D0271B65CAC0EE01999
# 49997                  33E03B2C4CD28CA4  B8E69AB58000AC3C272694D04DC2C256
# 49998                  33E06EE13B4DD920  0E5D5E87CFA2D024CC09098BA8F9E589
# 49999  33E0B1D54669E86824C7549692BBC2B7  EB0AA160D8768E0797E01F0DD9864850
#
#         DATA_HORA_ADMISSAO TIPO_EPISODIO IDADE GENERO  \
# 0      2354-04-29 00:00:00   Ambulatório  28.0      M
# 1      2022-01-28 15:25:45   Ambulatório  48.0      M
# 2      2358-01-13 00:00:00   Ambulatório  29.0      F
# 3      2357-07-17 00:00:00   Ambulatório  60.0      F
# 4      2360-12-15 00:00:00   Ambulatório  41.0      F
# ...                    ...           ...   ...    ...
# 49995  2360-12-01 00:00:00   Ambulatório  85.0      F
# 49996  2358-01-27 00:00:00   Ambulatório  56.0      F
# 49997  2353-05-21 00:00:00   Ambulatório  53.0      F
# 49998  2354-06-07 00:00:00   Ambulatório  48.0      M
# 49999  2360-10-06 00:00:00   Ambulatório  39.0      F
#
#                           ESPECIALIDADE                 DEMO_INFO     ICD9  \
# 0                          [Enfermagem]  [DEMO, DEMO, DEMO, DEMO]       []
# 1                   [Saude e Bem Estar]  [DEMO, DEMO, DEMO, DEMO]       []
# 2                          [Enfermagem]  [DEMO, DEMO, DEMO, DEMO]       []
# 3                          [Radiologia]  [DEMO, DEMO, DEMO, DEMO]       []
# 4                          [Neurologia]  [DEMO, DEMO, DEMO, DEMO]       []
# ...                                 ...                       ...      ...
# 49995                     [Cardiologia]  [DEMO, DEMO, DEMO, DEMO]  [272.0]
# 49996                    [Oftalmologia]  [DEMO, DEMO, DEMO, DEMO]       []
# 49997         [Ginecologia/Obstetrícia]  [DEMO, DEMO, DEMO, DEMO]       []
# 49998                      [Radiologia]  [DEMO, DEMO, DEMO, DEMO]       []
# 49999  [Medicina Física e Reabilitação]  [DEMO, DEMO, DEMO, DEMO]       []
#
#       ICD9_INFO                                               DIAG  \
# 0            []                                                 []
# 1            []                                                 []
# 2            []                                                 []
# 3            []                                                 []
# 4            []                                                 []
# ...         ...                                                ...
# 49995    [ICD9]  [ansiedade, s. depressivo, hipotiroidismo, dis...
# 49996        []                                                 []
# 49997        []                                                 []
# 49998        []                                                 []
# 49999        []                                                 []
#
#                                                DIAG_INFO     ANTPESSOAIS  \
# 0                                                     []              []
# 1                                                     []              []
# 2                                                     []              []
# 3                                                     []              []
# 4                                                     []              []
# ...                                                  ...             ...
# 49995  [TEXT, TEXT, TEXT, TEXT, TEXT, TEXT, TEXT, TEX...  [Dislipidemia]
# 49996                                                 []              []
# 49997                                                 []              []
# 49998                                                 []              []
# 49999                                                 []              []
#
#       ANTPESSOAIS_INFO LABS LABS_INFO                MEDS   MEDS_INFO  \
# 0                   []   []        []                  []          []
# 1                   []   []        []                  []          []
# 2                   []   []        []                  []          []
# 3                   []   []        []                  []          []
# 4                   []   []        []                  []          []
# ...                ...  ...       ...                 ...         ...
# 49995            [ANT]   []        []  [C09CA08, C10AA05]  [ATC, ATC]
# 49996               []   []        []                  []          []
# 49997               []   []        []                  []          []
# 49998               []   []        []                  []          []
# 49999               []   []        []                  []          []
#
#                               CRONICAS  \
# 0                                   []
# 1                                   []
# 2                                   []
# 3                                   []
# 4                                   []
# ...                                ...
# 49995  [Depression, HTN, Dyslipidemia]
# 49996                               []
# 49997                               []
# 49998                               []
# 49999                               []
#
#                                      PATOLOGIAS       CRONICAS_INFO  \
# 0                                            []                  []
# 1                                            []                  []
# 2                                            []                  []
# 3                                            []                  []
# 4                                            []                  []
# ...                                         ...                 ...
# 49995  [Psychiatric, Cardiovascular, Endocrine]  [CRON, CRON, CRON]
# 49996                                        []                  []
# 49997                                        []                  []
# 49998                                        []                  []
# 49999                                        []                  []
#
#        PATOLOGIAS_INFO                                             VECTOR  \
# 0                   []                 [Ambulatório, 28.0, Enfermagem, M]
# 1                   []          [Ambulatório, 48.0, Saude e Bem Estar, M]
# 2                   []                 [Ambulatório, 29.0, Enfermagem, F]
# 3                   []                 [Ambulatório, 60.0, Radiologia, F]
# 4                   []                 [Ambulatório, 41.0, Neurologia, F]
# ...                ...                                                ...
# 49995  [PAT, PAT, PAT]  [Ambulatório, 85.0, Cardiologia, F, 272.0, C09...
# 49996               []               [Ambulatório, 56.0, Oftalmologia, F]
# 49997               []    [Ambulatório, 53.0, Ginecologia/Obstetrícia, F]
# 49998               []                 [Ambulatório, 48.0, Radiologia, M]
# 49999               []  [Ambulatório, 39.0, Medicina Física e Reabilit...
#
#                                                     INFO
# 0                               [DEMO, DEMO, DEMO, DEMO]
# 1                               [DEMO, DEMO, DEMO, DEMO]
# 2                               [DEMO, DEMO, DEMO, DEMO]
# 3                               [DEMO, DEMO, DEMO, DEMO]
# 4                               [DEMO, DEMO, DEMO, DEMO]
# ...                                                  ...
# 49995  [DEMO, DEMO, DEMO, DEMO, ICD9, ATC, ATC, CRON,...
# 49996                           [DEMO, DEMO, DEMO, DEMO]
# 49997                           [DEMO, DEMO, DEMO, DEMO]
# 49998                           [DEMO, DEMO, DEMO, DEMO]
# 49999                           [DEMO, DEMO, DEMO, DEMO]
#
# [50000 rows x 24 columns]
